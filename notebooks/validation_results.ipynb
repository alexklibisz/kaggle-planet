# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import datetime
import numpy as np
import sys; sys.path.append('..')
from planet.utils.data_utils import val_plot_metrics, val_plot_predictions, TAGS_short
print('Done')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Done

# %%
print(str(datetime.datetime.now()))
val_plot_metrics('../checkpoints/val_data_114.pkl')
# Out:
# 2017-06-30 23:08:06.080689
# agriculture
# artisinal_mine
# bare_ground
# blooming
# blow_down
# clear
# cloudy
# conventional_mine
# cultivation
# habitation
# haze
# partly_cloudy
# primary
# road
# selective_logging
# slash_burn
# water

# %%
val_plot_predictions('../checkpoints/val_data_114.pkl')
# Out:
# /home/gbruer/envs/py3ml/lib/python3.5/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# I'm sorry if the x-axis labels are all shifted messed. I'll try to fix that eventually
